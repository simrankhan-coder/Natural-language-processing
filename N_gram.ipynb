# %%
import re
import numpy as np
import pandas as pd
from tqdm import tqdm

with open('big.txt','r') as fd:
    lines = fd.readlines()
    words = []
    for line in lines:
        words += re.findall('\w+', line.lower())
# Out:
# <>:10: SyntaxWarning: invalid escape sequence '\w'
# <>:10: SyntaxWarning: invalid escape sequence '\w'
# /tmp/ipykernel_26949/2646962661.py:10: SyntaxWarning: invalid escape sequence '\w'
#   words += re.findall('\w+', line.lower())

# %% [markdown]
# ###Finding the Pairs

# %%
def get_pairs(words,n):
    n=n+1
    data = []
    for i in range(len(words)-n):
        data.append(' '.join(words[i:i+n]))
    return data

# %% [markdown]
# ##Finding Occurence Probabilities

# %%
def get_prob_dist(data):
    a = np.array(data)
    pair , count = np.unique(a, return_counts = True)
    unique_pairs = list(set(data))

    prob_dist = []

    for i in range(len(unique_pairs)):
        prob_dist.append([unique_pairs[i] , ' '.join(unique_pairs[i].split(' ')[:-1]), unique_pairs[i].split(' ')[-1], count[i]])

    return prob_dist

# %%
data = get_pairs(words,4)
prob_dist = get_prob_dist(data)

# %% [markdown]
# ##Predicting the Words

# %%
df = pd.DataFrame(prob_dist, columns = ['seq','inp','out','freq'])
df.head()

def predict(word):
    if len(df[df['inp'] == word]):
        df_ = df[df['inp'] == word]
        return df_.sort_values(by = 'freq').head()['out'].values
    else:
        print('Seq is not present')

predict('this is a beautiful')
# Out:
# array(['country'], dtype=object)

# %% [markdown]
# ## Prediction for One Word

# %%
predict('this is not a')
# Out:
# array(['sewing', 'power', 'time', 'joke', 'state'], dtype=object)

# %% [markdown]
# ##Prediction with auto Sequencing

# %%
def pred_seq(seq,n):

    output = []
    output.append(seq)

    for i in range(n):

        pred = predict(seq)
        seq = ' '.join(seq.split(' ')[1:]) + ' ' + pred[0]
        output.append(pred[0])

    return ' '.join(output)

pred_seq('the united states of', 50)
# Out:
# 'the united states of america_ _ series _ epochs of american history edited by a b hart hart a b _formation of the union_ thwaites r g _the colonies_ wilson woodrow _division and reunion_ riverside series edited by w e dodd becker c l _beginnings of the american people_ dodd w e _expansion and'
